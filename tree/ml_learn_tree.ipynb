# %%
import pandas as pd
import numpy as np
import sys

data = pd.read_csv('titanic.csv', index_col='PassengerId', usecols=["PassengerId", "Pclass", "Fare", "Age", "Sex", "Survived"])
print data.head()
print '---\ntypes\n---\n'
print data.dtypes

print len(data)

data = data[data.Age.notnull()]

clear_data = data.dropna(subset=['Pclass', 'Fare', 'Age', 'Survived', 'Sex'])
clear_data = clear_data.replace(to_replace=['male', 'female'], value=[1, 0])

print len(clear_data)
# Out:
#              Survived  Pclass     Sex  Age     Fare
# PassengerId
# 1                   0       3    male   22   7.2500
# 2                   1       1  female   38  71.2833
# 3                   1       3  female   26   7.9250
# 4                   1       1  female   35  53.1000
# 5                   0       3    male   35   8.0500
# ---
# types
# ---
#
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# Fare        float64
# dtype: object
# 891
# 714

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=241)
X = clear_data[['Pclass', 'Sex', 'Age', 'Fare']] 
y = clear_data[['Survived']] 
clf.fit(X, y)
importances = clf.feature_importances_
print importances
# Out:
# [ 0.14000522  0.30051221  0.2560461   0.30343647]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(clear_data.index , clear_data[['Age']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(data.index , data[['Survived']])
